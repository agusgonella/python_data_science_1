# %% [markdown]
# <a href="https://colab.research.google.com/github/agusgonella/python_data_science_1/blob/main/inmuebles_cdmx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas
# Importando la BD

# %%
import pandas as pd

# %%
url = 'https://gist.githubusercontent.com/ahcamachod/a572cfcc2527046db93101f88011b26e/raw/ffb13f45a79d31223e645611a119397dd127ee3c/alquiler.csv'

# %%
datos = pd.read_csv(url, sep=';')
datos
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1                         Casa               Polanco             2        0
# 2      Conjunto Comercial/Sala              Santa Fe             0        4
# 3                 Departamento      Centro Histórico             1        0
# 4                 Departamento             Del Valle             1        0
# ...                        ...                   ...           ...      ...
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# ...

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto
# 0    40   5950.0      1750.0     210.0
# 1   100  24500.0         NaN       NaN
# 2   150  18200.0     14070.0    3888.5
# 3    15   2800.0      1365.0      70.0
# 4    48   2800.0       805.0       NaN

# %%
datos.tail()
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 25116  Cochera/Estacionamiento      Centro Histórico             0        0
# 25117                 Cocineta      Centro Histórico             0        0
# 25118             Departamento               Mixcoac             2        1
# 25119             Departamento  Lomas de Chapultepec             2        0
# 25120  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area    Valor  Condominio  Impuesto
# 25116       0   755  49000.0         NaN       NaN
# 25117       0    27   2800.0      1225.0      87.5
# 25118       0    48   4900.0      1781.5     129.5
# 25119       0    70  10500.0      2660.0       NaN
# 25120       0   250  22750.0     14721.0    3881.5

# %%
datos.head(10)
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 5       Casa de Condominio          Santa Fe             5        4       5
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
# 7             Departamento  Centro Histórico             1        0       0
# 8             Departamento           Condesa             1        0       1
# 9                 Cocineta           Condesa             1        0       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 1   100   24500.0         NaN       NaN
# ...

# %%
datos.sample(10)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 18555             Departamento          Santa Fe             3        2
# 24639             Departamento           Condesa             4        2
# 13902  Conjunto Comercial/Sala          Santa Fe             0       28
# 198               Tienda/Salón          Santa Fe             0        8
# 15362  Conjunto Comercial/Sala  Centro Histórico             0        0
# 23255  Conjunto Comercial/Sala          Santa Fe             0        1
# 24151  Conjunto Comercial/Sala  Centro Histórico             0       18
# 8382                  Cocineta          Coyoacán             1        0
# 2098              Departamento           Condesa             3        0
# 19397             Departamento          Coyoacán             4        1
#
#        Suites  Area     Valor  Condominio  Impuesto
# 18555       1   120   22750.0      4186.0       NaN
# 24639       2   389   41300.0     14465.5    4035.5
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ##Exploracion inicial de los datos

# %%
datos.sample(5)
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 25009             Departamento              Roma             2        1
# 12488             Departamento          Coyoacán             4        2
# 23321  Galpón/Depósito/Almacén   Villa de Cortés             0        0
# 13831  Conjunto Comercial/Sala  Centro Histórico             0        6
# 11156             Departamento           Condesa             3        1
#
#        Suites  Area     Valor  Condominio  Impuesto
# 25009       1    52   10850.0      5950.0    1155.0
# 12488       3   380  104650.0     17500.0       NaN
# 23321       0   650   28000.0         NaN       NaN
# 13831       0  2580  858109.0    225820.0       NaN
# 11156       0   200   24500.0      5950.0    1820.0

# %%
datos.shape
# Out:
# (25121, 9)

# %%
datos.columns
# Out:
# Index(['Tipo', 'Colonia', 'Habitaciones', 'Garages', 'Suites', 'Area', 'Valor',
#        'Condominio', 'Impuesto'],
#       dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25121 entries, 0 to 25120
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          25121 non-null  object
#  1   Colonia       25121 non-null  object
#  2   Habitaciones  25121 non-null  int64
#  3   Garages       25121 non-null  int64
#  4   Suites        25121 non-null  int64
#  5   Area          25121 non-null  int64
#  6   Valor         25107 non-null  float64
#  7   Condominio    22495 non-null  float64
#  8   Impuesto      18037 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos['Tipo']
# Out:
# 0                       Cocineta
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                   Departamento
# 4                   Departamento
#                   ...
# 25116    Cochera/Estacionamiento
# 25117                   Cocineta
# 25118               Departamento
# 25119               Departamento
# 25120    Conjunto Comercial/Sala
# Name: Tipo, Length: 25121, dtype: object

# %%
datos[['Habitaciones','Valor']]
# Out:
#        Habitaciones    Valor
# 0                 1   5950.0
# 1                 2  24500.0
# 2                 0  18200.0
# 3                 1   2800.0
# 4                 1   2800.0
# ...             ...      ...
# 25116             0  49000.0
# 25117             0   2800.0
# 25118             2   4900.0
# 25119             2  10500.0
# 25120             0  22750.0
#
# [25121 rows x 2 columns]

# %%
datos.describe()
# Out:
#        Habitaciones       Garages        Suites          Area         Valor  \
# count  25121.000000  25121.000000  25121.000000  25121.000000  2.510700e+04
# mean       1.748856      1.798655      0.656781    220.885076  3.688505e+04
# std        1.811131     22.906129      1.083180    817.465428  3.669381e+05
# min        0.000000      0.000000      0.000000      0.000000  3.150000e+02
# 25%        0.000000      0.000000      0.000000     55.000000  5.600000e+03
# 50%        2.000000      1.000000      0.000000     90.000000  1.137500e+04
# 75%        3.000000      2.000000      1.000000    180.000000  2.695000e+04
# max      100.000000   1966.000000     24.000000  42000.000000  5.250000e+07
#
#          Condominio      Impuesto
# count  2.249500e+04  1.803700e+04
# mean   9.528676e+03  4.436513e+03
# std    1.547102e+05  2.283381e+04
# min    3.500000e+00  3.500000e+00
# 25%    2.275000e+03  4.270000e+02
# 50%    4.056500e+03  1.008000e+03
# 75%    7.350000e+03  2.625000e+03
# ...

# %% [markdown]
# ##Demandas de ML

# %%
#Valores promedio de alquiler por tipo de propiedad
datos['Valor'].mean() #Pero yo necesito para cada tipo...
# Out:
# np.float64(36885.05048392878)

# %%
datos.groupby('Tipo').mean(numeric_only=True)
# Out:
#                             Habitaciones    Garages     Suites          Area  \
# Tipo
# Casa                            3.359633   1.897248   1.438532    289.943119
# Casa Comercial                  1.801980   2.118812   0.257426    370.277228
# Casa de Condominio              4.319672   3.555738   3.247541    566.303279
# Casa de Vecindad                1.974684   0.379747   0.215190     79.981013
# Cochera/Estacionamiento         0.064935   1.376623   0.000000     18.662338
# Cocineta                        0.836088   0.020661   0.041322     29.090909
# Conjunto Comercial/Sala         0.047175   2.686323   0.000352    236.323711
# Departamento                    2.504199   1.256367   0.891899    124.014292
# Departamento en Hotel           1.419780   0.969231   0.758242     65.848352
# Edificio Completo               0.405530  11.175115   0.027650   1717.271889
# Estudio                         0.500000   0.250000   0.000000    103.250000
# ...

# %%
datos.groupby('Tipo')['Valor'].mean()
# Out:
# Tipo
# Casa                           31453.177064
# Casa Comercial                 54735.841584
# Casa de Condominio             51428.609836
# Casa de Vecindad                5961.740506
# Cochera/Estacionamiento         6995.454545
# Cocineta                        4425.856061
# Conjunto Comercial/Sala        57675.214550
# Departamento                   18683.269431
# Departamento en Hotel          16285.430769
# Edificio Completo             409418.080645
# Estudio                         8400.000000
# Galpón/Depósito/Almacén       299984.140138
# Hotel                          87500.000000
# Industria                     420000.000000
# Loft                            9924.526316
# Loteo/Condominio               92166.666667
# Posada/Chalé                    5180.000000
# Rancho                         38014.375000
# Terreno Estándar              135364.444444
# Tienda en Centro Comercial     32556.785714
# Tienda/Salón                   56263.544252
# ...

# %%
datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                     Valor
# Tipo
# Cocineta                      4425.856061
# Posada/Chalé                  5180.000000
# Casa de Vecindad              5961.740506
# Cochera/Estacionamiento       6995.454545
# Estudio                       8400.000000
# Loft                          9924.526316
# Departamento en Hotel        16285.430769
# Departamento                 18683.269431
# Casa                         31453.177064
# Tienda en Centro Comercial   32556.785714
# Rancho                       38014.375000
# Casa de Condominio           51428.609836
# Casa Comercial               54735.841584
# Tienda/Salón                 56263.544252
# Conjunto Comercial/Sala      57675.214550
# Hotel                        87500.000000
# Loteo/Condominio             92166.666667
# Terreno Estándar            135364.444444
# Galpón/Depósito/Almacén     299984.140138
# Edificio Completo           409418.080645
# Industria                   420000.000000

# %%
df_tipo_precio = datos.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_tipo_precio.plot(kind='barh',figsize=(12,8),color='pink')
# Out:
# <Axes: ylabel='Tipo'>

# %%
#Porcentaje de cada tipo de inmueble
datos.Tipo.unique()
# Out:
# array(['Cocineta', 'Casa', 'Conjunto Comercial/Sala', 'Departamento',
#        'Casa de Condominio', 'Edificio Completo', 'Departamento en Hotel',
#        'Tienda/Salón', 'Casa Comercial', 'Casa de Vecindad',
#        'Terreno Estándar', 'Cochera/Estacionamiento', 'Loft',
#        'Galpón/Depósito/Almacén', 'Tienda en Centro Comercial', 'Rancho',
#        'Posada/Chalé', 'Estudio', 'Hotel', 'Loteo/Condominio',
#        'Industria'], dtype=object)

# %%
datos.Tipo.value_counts()
# Out:
# Tipo
# Departamento                  14764
# Conjunto Comercial/Sala        5681
# Tienda/Salón                   1098
# Cocineta                        726
# Casa de Condominio              610
# Casa                            545
# Departamento en Hotel           455
# Galpón/Depósito/Almacén         289
# Edificio Completo               217
# Casa Comercial                  202
# Tienda en Centro Comercial      197
# Casa de Vecindad                158
# Cochera/Estacionamiento          77
# Terreno Estándar                 45
# Loft                             38
# Rancho                            8
# Estudio                           4
# Loteo/Condominio                  3
# Hotel                             2
# Posada/Chalé                      1
# Industria                         1
# Name: count, dtype: int64

# %%
datos.Tipo.value_counts(normalize=True)
# Out:
# Tipo
# Departamento                  0.587715
# Conjunto Comercial/Sala       0.226145
# Tienda/Salón                  0.043708
# Cocineta                      0.028900
# Casa de Condominio            0.024282
# Casa                          0.021695
# Departamento en Hotel         0.018112
# Galpón/Depósito/Almacén       0.011504
# Edificio Completo             0.008638
# Casa Comercial                0.008041
# Tienda en Centro Comercial    0.007842
# Casa de Vecindad              0.006290
# Cochera/Estacionamiento       0.003065
# Terreno Estándar              0.001791
# Loft                          0.001513
# Rancho                        0.000318
# Estudio                       0.000159
# Loteo/Condominio              0.000119
# Hotel                         0.000080
# Posada/Chalé                  0.000040
# Industria                     0.000040
# Name: proportion, dtype: float64

# %%
porcentaje_tipo = datos.Tipo.value_counts(normalize = True).to_frame()
porcentaje_tipo.plot(kind='bar',figsize = (12,8), color ='green', xlabel='Tipos',ylabel='Porcentajes')
# Out:
# <Axes: xlabel='Tipos', ylabel='Porcentajes'>

# %%
df = datos.query('Tipo == "Departamento"')
df.head()
# Out:
#             Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3   Departamento  Centro Histórico             1        0       0    15
# 4   Departamento         Del Valle             1        0       0    48
# 7   Departamento  Centro Histórico             1        0       0    36
# 8   Departamento           Condesa             1        0       1    40
# 10  Departamento           Condesa             4        3       1   243
#
#       Valor  Condominio  Impuesto
# 3    2800.0      1365.0      70.0
# 4    2800.0       805.0       NaN
# 7    4200.0         NaN       NaN
# 8    7000.0      1963.5     175.0
# 10  45500.0      7000.0    2810.5

# %%
df.shape
# Out:
# (14764, 9)

# %%
# Calcular el promedio de habitaciones por departamento.
datos.sample(5)
# Out:
#                  Tipo    Colonia  Habitaciones  Garages  Suites  Area  \
# 19003    Departamento  Nativitas             2        1       0    54
# 13059    Departamento  San Ángel             3        0       1   115
# 23300  Casa Comercial  Iztacalco             3        2       0   225
# 19460    Tienda/Salón   Santa Fe             2        6       2   100
# 1153     Departamento   Coyoacán             3        1       1   108
#
#          Valor  Condominio  Impuesto
# 19003   3850.0      1575.0     210.0
# 13059   9450.0      3080.0     623.0
# 23300  10500.0         NaN       NaN
# 19460  14000.0     10010.0   52500.0
# 1153   28000.0      4732.0    1225.0

# %%
promedio_habitaciones = datos.query('Tipo == "Departamento"').Habitaciones.mean()
print(promedio_habitaciones)
# Out:
# 2.5041994039555675

# %%
#En realidad, era mas facil:
print(datos['Habitaciones'].mean())
# Out:
# 1.7488555391903189

# %%
#Verificar cuántas colonias únicas existen en nuestra base de datos.
len(datos.Colonia.unique()) #Recorda que las funciones de python siguen pudiendo usarse...
# Out:
# 88

# %%
#Analizar qué colonias tienen el promedio de alquiler más alto.
mas_caros = datos.groupby('Colonia')[['Valor']].mean().sort_values('Valor', ascending=False)
mas_caros
# Out:
#                               Valor
# Colonia
# San Juan Xalpa        420926.739130
# Nativitas             244684.395062
# La Merced             213292.770833
# Santa Marta Acatitla  166048.105263
# Villa de Cortés       135737.411765
# ...                             ...
# Álvaro Obregón          3048.281250
# San José Insurgentes    2660.000000
# El Rodeo                2586.111111
# Tláhuac                 2481.818182
# Las Aguilas             2222.500000
#
# [88 rows x 1 columns]

# %%
#Crear un gráfico de barras horizontales que muestre las 5 colonias con los promedios de alquiler más altos.
grafico = mas_caros.head(5)
grafico.plot(kind='barh',figsize = (12,8), color ='blue')
# Out:
# <Axes: ylabel='Colonia'>

# %%
##Tratando los datos nulos: identificandolos y luego tratandolos

# %%
datos.isnull()
# Out:
#         Tipo  Colonia  Habitaciones  Garages  Suites   Area  Valor  \
# 0      False    False         False    False   False  False  False
# 1      False    False         False    False   False  False  False
# 2      False    False         False    False   False  False  False
# 3      False    False         False    False   False  False  False
# 4      False    False         False    False   False  False  False
# ...      ...      ...           ...      ...     ...    ...    ...
# 25116  False    False         False    False   False  False  False
# 25117  False    False         False    False   False  False  False
# 25118  False    False         False    False   False  False  False
# 25119  False    False         False    False   False  False  False
# 25120  False    False         False    False   False  False  False
#
#        Condominio  Impuesto
# 0           False     False
# 1            True      True
# 2           False     False
# 3           False     False
# ...

# %%
datos.isnull().sum()
# Out:
# Tipo               0
# Colonia            0
# Habitaciones       0
# Garages            0
# Suites             0
# Area               0
# Valor             14
# Condominio      2626
# Impuesto        7084
# dtype: int64

# %%
df = datos.fillna(0)
df.isnull().sum()
# Out:
# Tipo            0
# Colonia         0
# Habitaciones    0
# Garages         0
# Suites          0
# Area            0
# Valor           0
# Condominio      0
# Impuesto        0
# dtype: int64

# %%
#Remover registros inconsistentes

#Removiendo departamentos con valor igual a 0 o con condominio igual a 0

df.query('Valor==0 | Condominio==0').index
# Out:
# Index([    1,     5,     7,    11,    24,    49,    53,    74,    78,    96,
#        ...
#        25010, 25014, 25029, 25032, 25053, 25055, 25086, 25098, 25099, 25116],
#       dtype='int64', length=2638)

# %%
df_remover = df.query('Valor==0 | Condominio==0').index

# %%
df.drop(df_remover, axis=0, inplace=True)

# %%
df.query('Valor==0 | Condominio==0').index
# Out:
# Index([], dtype='int64')

# %%
df.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
# 6  Conjunto Comercial/Sala  Centro Histórico             0        3       0
#
#    Area     Valor  Condominio  Impuesto
# 0    40    5950.0      1750.0     210.0
# 2   150   18200.0     14070.0    3888.5
# 3    15    2800.0      1365.0      70.0
# 4    48    2800.0       805.0       0.0
# 6   695  122500.0     67175.5   10605.0

# %%
#Filtrar en:
#Apartamentos con 1 solo dormitorio y alquiler < a 4200

seleccion1 = df['Habitaciones'] == 1

# %%
seleccion1
# Out:
# 0         True
# 2        False
# 3         True
# 4         True
# 6        False
#          ...
# 25115    False
# 25117    False
# 25118    False
# 25119    False
# 25120    False
# Name: Habitaciones, Length: 22483, dtype: bool

# %%
df[seleccion1]
# Out:
#                Tipo               Colonia  Habitaciones  Garages  Suites  \
# 0          Cocineta               Condesa             1        0       0
# 3      Departamento      Centro Histórico             1        0       0
# 4      Departamento             Del Valle             1        0       0
# 8      Departamento               Condesa             1        0       1
# 9          Cocineta               Condesa             1        0       0
# ...             ...                   ...           ...      ...     ...
# 25092  Departamento              Santa Fe             1        1       0
# 25100  Departamento  Lomas de Chapultepec             1        1       1
# 25103  Departamento               Condesa             1        0       0
# 25109      Cocineta               Condesa             1        0       0
# 25114  Departamento              Narvarte             1        0       0
#
#        Area    Valor  Condominio  Impuesto
# 0        40   5950.0      1750.0     210.0
# ...

# %%
seleccion2 = df['Valor'] < 4200

# %%
df[seleccion2]
# Out:
#                           Tipo           Colonia  Habitaciones  Garages  \
# 3                 Departamento  Centro Histórico             1        0
# 4                 Departamento         Del Valle             1        0
# 19                Departamento          Narvarte             1        0
# 37                Departamento  Centro Histórico             1        0
# 50     Conjunto Comercial/Sala          Santa Fe             0        1
# ...                        ...               ...           ...      ...
# 25096  Conjunto Comercial/Sala      Barrio Bravo             0        0
# 25104  Conjunto Comercial/Sala          Santa Fe             0        1
# 25112  Conjunto Comercial/Sala  Centro Histórico             0        0
# 25114             Departamento          Narvarte             1        0
# 25117                 Cocineta  Centro Histórico             0        0
#
#        Suites  Area   Valor  Condominio  Impuesto
# 3           0    15  2800.0      1365.0      70.0
# ...

# %%
df[seleccion2].max()
# Out:
# Tipo              Tienda/Salón
# Colonia         Álvaro Obregón
# Habitaciones                 5
# Garages                      9
# Suites                       2
# Area                      1628
# Valor                   4196.5
# Condominio            174475.0
# Impuesto               44625.0
# dtype: object

# %%
filtro1 = seleccion1 & seleccion2

# %%
df[filtro1]
# Out:
#                Tipo           Colonia  Habitaciones  Garages  Suites  Area  \
# 3      Departamento  Centro Histórico             1        0       0    15
# 4      Departamento         Del Valle             1        0       0    48
# 19     Departamento          Narvarte             1        0       0    48
# 37     Departamento  Centro Histórico             1        0       0    27
# 61     Departamento  Centro Histórico             1        1       0    37
# ...             ...               ...           ...      ...     ...   ...
# 24880  Departamento        La Condesa             1        0       0    46
# 24943  Departamento              Roma             1        0       0    21
# 24981      Cocineta        La Condesa             1        0       0    10
# 25039      Cocineta  Centro Histórico             1        0       0    24
# 25114  Departamento          Narvarte             1        0       0    28
#
#         Valor  Condominio  Impuesto
# ...

# %%
df1 = df[filtro1]

# %%
#Apartamentos que tienen al menos 2 dormitorios, alquiler menor a 10500 y superficie mayor a 70m2

# %%
filtro2 = (df['Habitaciones'] >=2) & (df['Valor']<10500) & (df['Area']>70)
df[filtro2]
# Out:
#                         Tipo   Colonia  Habitaciones  Garages  Suites  Area  \
# 14              Departamento  Narvarte             2        1       0   110
# 16              Departamento  Narvarte             2        1       0    78
# 21              Departamento      Roma             2        1       0    76
# 33              Departamento  Santa Fe             3        1       1    72
# 58              Departamento  Santa Fe             3        2       1   104
# ...                      ...       ...           ...      ...     ...   ...
# 25031  Departamento en Hotel  Santa Fe             2        1       2    77
# 25062           Departamento  Santa Fe             2        1       1    72
# 25063           Departamento  Narvarte             3        1       0    75
# 25105           Departamento  Santa Fe             2        1       1    85
# 25106           Departamento  Santa Fe             3        2       0    98
#
#         Valor  Condominio  Impuesto
# ...

# %%
df2 = df[filtro2]

# %%
#Almacenar los dataframe en formato csv

# %%
df.to_csv('inmuebles_ml.csv', index=False)

# %%
pd.read_csv('inmuebles_ml.csv')
# Out:
#                           Tipo               Colonia  Habitaciones  Garages  \
# 0                     Cocineta               Condesa             1        0
# 1      Conjunto Comercial/Sala              Santa Fe             0        4
# 2                 Departamento      Centro Histórico             1        0
# 3                 Departamento             Del Valle             1        0
# 4      Conjunto Comercial/Sala      Centro Histórico             0        3
# ...                        ...                   ...           ...      ...
# 22478       Casa de Condominio              Santa Fe             5        3
# 22479                 Cocineta      Centro Histórico             0        0
# 22480             Departamento               Mixcoac             2        1
# 22481             Departamento  Lomas de Chapultepec             2        0
# 22482  Conjunto Comercial/Sala      Centro Histórico             0        0
#
#        Suites  Area     Valor  Condominio  Impuesto
# ...

# %%
df.to_csv('inmuebles_ml.csv', index=False, sep=';')

# %%
df1.to_csv('inmuebles_ml_f1.csv', index=False, sep=';')
df2.to_csv('inmuebles_ml_f2.csv', index=False, sep=';')

# %%
#Ejercicios extras de la clase
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
#Verifica si la base de datos contiene datos nulos y, en caso de tenerlos,
#realiza el tratamiento de estos datos nulos de la manera que consideres más coherente con la situación.
datos.isnull()
# Out:
#     Nombre   Edad   Nota  Aprobado
# 0    False  False  False     False
# 1    False  False   True     False
# 2    False  False  False     False
# 3    False  False  False     False
# 4    False  False  False     False
# 5    False  False   True     False
# 6    False  False  False     False
# 7    False  False  False     False
# 8    False  False  False     False
# 9    False  False   True     False
# 10   False  False   True     False
# 11   False  False  False     False
# 12   False  False  False     False
# 13   False  False  False     False
# 14   False  False   True     False
# 15   False  False  False     False
# 16   False  False   True     False
# 17   False  False  False     False

# %%
datos.isnull().sum()
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
#No considero que sea adecuado eliminarlos por lo que los contaré
desaprobados = datos.isnull().sum()
desaprobados
# Out:
# Nombre      0
# Edad        0
# Nota        6
# Aprobado    0
# dtype: int64

# %%
datos = datos.fillna(0)
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
#Los estudiantes "Alicia" y "Carlos" ya no forman parte del grupo. Por lo tanto, elimínalos de la base de datos.
sacar = datos.query('Nombre == "Alicia" | Nombre == "Carlos"').index
datos.drop(sacar, axis=0, inplace=True)
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
#Aplica un filtro que seleccione solo a los estudiantes que fueron aprobados.

# %%
datos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   0.0      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   0.0      False
# 6    Daniela    21   7.0       True
# 9     Victor    28   0.0      False
# 10    Danilo    21   0.0      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   0.0      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   0.0      False
# 17     Nadia    34   8.0  Verdadero

# %%
aprobados = datos['Nota'] >= 7.0
#Aca no se que paso porque hice lo mismo que ellos pero como que me esta eliminando todo, no etniedno. Lo hice con nota y funciono pero con 'Aprobado' (como lo hicieron ellos) NO.

# %%
datos[aprobados]
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 4      Brian    21  10.0       True
# 6    Daniela    21   7.0       True
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 15    Milena    29   7.0       True
# 17     Nadia    34   8.0  Verdadero

# %%
aprobados2 = datos['Aprobado'] == True

# %%
datos[aprobados2]
# Out:
# Empty DataFrame
# Columns: [Nombre, Edad, Nota, Aprobado]
# Index: []

# %%
#Manipulacion de datos

# %%
#Crear columna valor_mensual y valor_anual
datos = pd.read_csv(url, sep=';')
datos.shape
# Out:
# (25121, 9)

# %%
datos['Valor_mensual'] = datos['Valor'] + datos['Condominio']
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual
# 0    40   5950.0      1750.0     210.0         7700.0
# 1   100  24500.0         NaN       NaN            NaN
# 2   150  18200.0     14070.0    3888.5        32270.0
# 3    15   2800.0      1365.0      70.0         4165.0
# 4    48   2800.0       805.0       NaN         3605.0

# %%
datos['Valor_anual'] = datos['Valor_mensual']*12 + datos['Impuesto']
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN

# %%
#Columna de resumen clave de las propiedades: tipo, barrio, habitaciones y plazas de estacionamiento

# %%
datos['Descripcion'] = datos['Tipo'] + ' en la Colonia ' + datos['Colonia'] + ' con: ' + datos['Habitaciones'].astype(str) + ' habitaciones y ' + datos['Garages'].astype(str) + ' plazas de estacionamiento'

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion
# ...

# %%
datos.iloc[500].Descripcion
# Out:
# 'Departamento en la Colonia Napoles con: 1 habitaciones y 0 plazas de estacionamiento'

# %%
#Columna que indica si tiene suite o no
datos['Tiene_suite'] = datos['Suites'].apply(lambda x: 'Si' if x > 0 else 'No')

# %%
datos.head()
# Out:
#                       Tipo           Colonia  Habitaciones  Garages  Suites  \
# 0                 Cocineta           Condesa             1        0       0
# 1                     Casa           Polanco             2        0       1
# 2  Conjunto Comercial/Sala          Santa Fe             0        4       0
# 3             Departamento  Centro Histórico             1        0       0
# 4             Departamento         Del Valle             1        0       0
#
#    Area    Valor  Condominio  Impuesto  Valor_mensual  Valor_anual  \
# 0    40   5950.0      1750.0     210.0         7700.0      92610.0
# 1   100  24500.0         NaN       NaN            NaN          NaN
# 2   150  18200.0     14070.0    3888.5        32270.0     391128.5
# 3    15   2800.0      1365.0      70.0         4165.0      50050.0
# 4    48   2800.0       805.0       NaN         3605.0          NaN
#
#                                          Descripcion Tiene_suite
# ...

# %%
#Mas ejercicios
url2 = 'https://gist.githubusercontent.com/ahcamachod/807a2c1cf6c19108b2b701ea1791ab45/raw/fb84f8b2d8917a89de26679eccdbc8f9c1d2e933/alumnos.csv'
alumnos = pd.read_csv(url2, sep=',')
alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado
# 0    Alberto    20   7.5       True
# 1        Ana    18   NaN      False
# 2     Camila    27   2.5      False
# 3      David    18   5.0      False
# 4      Brian    21  10.0       True
# 5      Bruna    23   NaN      False
# 6    Daniela    21   7.0       True
# 7     Carlos    19   6.0      False
# 8     Alicia    35   5.6      False
# 9     Victor    28   NaN      False
# 10    Danilo    21   NaN      False
# 11   Ignacio    24   4.5      False
# 12  Stephany    26  10.0       True
# 13    Miriam    25   9.0       True
# 14     Pablo    37   NaN      False
# 15    Milena    29   7.0       True
# 16     Lucas    33   NaN      False
# 17     Nadia    34   8.0  Verdadero

# %%
#Los estudiantes participaron en una actividad extracurricular y ganaron puntos extras. Estos puntos extras corresponden al 40% de su nota actual.
#Por lo tanto, crea una columna llamada "Puntos_extras" que contenga los puntos extras de cada estudiante, es decir, el 40% de su nota actual.

alumnos['Puntos_extras'] = alumnos['Nota']*0.4

# %%
alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extras
# 0  Alberto    20   7.5     True            3.0
# 1      Ana    18   NaN    False            NaN
# 2   Camila    27   2.5    False            1.0
# 3    David    18   5.0    False            2.0
# 4    Brian    21  10.0     True            4.0

# %%
#Crea otra columna llamada "Notas_finales" que contenga las notas de cada estudiante sumadas con los puntos extras
alumnos['Notas_finales'] = alumnos['Nota'] + alumnos['Puntos_extras']
alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales
# 0  Alberto    20   7.5     True            3.0           10.5
# 1      Ana    18   NaN    False            NaN            NaN
# 2   Camila    27   2.5    False            1.0            3.5
# 3    David    18   5.0    False            2.0            7.0
# 4    Brian    21  10.0     True            4.0           14.0

# %%
#Dado que hubo una puntuación extra, algunos estudiantes que no habían sido aprobados antes pueden haber sido aprobados ahora. En función de esto, crea una columna llamada "Aprobado_final" con los siguientes valores:

#True: si el estudiante está aprobado (la nota final debe ser mayor o igual a 7.0).
#False: si el estudiante está reprobado (la nota final debe ser menor que 7.0).

alumnos['Aprobado_final'] = alumnos['Notas_finales'].apply(lambda x: True if x >= 7.0 else False)
alumnos.head()
# Out:
#     Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 0  Alberto    20   7.5     True            3.0           10.5            True
# 1      Ana    18   NaN    False            NaN            NaN           False
# 2   Camila    27   2.5    False            1.0            3.5           False
# 3    David    18   5.0    False            2.0            7.0            True
# 4    Brian    21  10.0     True            4.0           14.0            True

# %%
alumnos
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5       True           3.00          10.50
# 1        Ana    18   NaN      False            NaN            NaN
# 2     Camila    27   2.5      False           1.00           3.50
# 3      David    18   5.0      False           2.00           7.00
# 4      Brian    21  10.0       True           4.00          14.00
# 5      Bruna    23   NaN      False            NaN            NaN
# 6    Daniela    21   7.0       True           2.80           9.80
# 7     Carlos    19   6.0      False           2.40           8.40
# 8     Alicia    35   5.6      False           2.24           7.84
# 9     Victor    28   NaN      False            NaN            NaN
# 10    Danilo    21   NaN      False            NaN            NaN
# 11   Ignacio    24   4.5      False           1.80           6.30
# 12  Stephany    26  10.0       True           4.00          14.00
# ...

# %%
#Realiza una selección y verifica qué estudiantes no habían sido aprobados anteriormente,
#pero ahora fueron aprobados después de sumar los puntos extras ---> Me sigue dando problemas al hacerlo igual que ellos, voy a chequear por nota en vez de aprobado

#Me elimina los alumnos, no se bien que pasa pero conceptualmente lo estoy haciendo ifual que me enseñaron asi que esta bien...

seleccion = alumnos['Nota'] < 7.0
alumnos[seleccion]
# Out:
#      Nombre  Edad  Nota Aprobado  Puntos_extras  Notas_finales  Aprobado_final
# 2    Camila    27   2.5    False           1.00           3.50           False
# 3     David    18   5.0    False           2.00           7.00            True
# 7    Carlos    19   6.0    False           2.40           8.40            True
# 8    Alicia    35   5.6    False           2.24           7.84            True
# 11  Ignacio    24   4.5    False           1.80           6.30           False

# %%
seleccion2 = alumnos['Aprobado_final'] == True
alumnos[seleccion2]
# Out:
#       Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales  \
# 0    Alberto    20   7.5       True           3.00          10.50
# 3      David    18   5.0      False           2.00           7.00
# 4      Brian    21  10.0       True           4.00          14.00
# 6    Daniela    21   7.0       True           2.80           9.80
# 7     Carlos    19   6.0      False           2.40           8.40
# 8     Alicia    35   5.6      False           2.24           7.84
# 12  Stephany    26  10.0       True           4.00          14.00
# 13    Miriam    25   9.0       True           3.60          12.60
# 15    Milena    29   7.0       True           2.80           9.80
# 17     Nadia    34   8.0  Verdadero           3.20          11.20
#
#     Aprobado_final
# 0             True
# 3             True
# 4             True
# 6             True
# 7             True
# 8             True
# 12            True
# 13            True
# 15            True
# 17            True

# %%
filtro = seleccion1 & seleccion2
alumnos[filtro]
# Out:
# /tmp/ipython-input-262481861.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   alumnos[filtro]
#      Nombre  Edad  Nota   Aprobado  Puntos_extras  Notas_finales  \
# 0   Alberto    20   7.5       True           3.00          10.50
# 3     David    18   5.0      False           2.00           7.00
# 4     Brian    21  10.0       True           4.00          14.00
# 8    Alicia    35   5.6      False           2.24           7.84
# 17    Nadia    34   8.0  Verdadero           3.20          11.20
#
#     Aprobado_final
# 0             True
# 3             True
# 4             True
# 8             True
# 17            True
