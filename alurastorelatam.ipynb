# %% [markdown]
# <a href="https://colab.research.google.com/github/agusgonella/python_data_science_1/blob/main/alurastorelatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()

#lat = latitud y lon = longitud -> Son las coordenadas
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda.sample(7)
# Out:
#                        Producto   Categoría del Producto     Precio  \
# 368           Balón de voleibol     Deportes y diversión    40300.0
# 796   Auriculares con micrófono             Electrónicos   244100.0
# 1522             Mesa de centro                  Muebles   173400.0
# 309     Bloques de construcción                 Juguetes    37000.0
# 304                  Cubertería  Artículos para el hogar    49400.0
# 887            Lavadora de ropa        Electrodomésticos  1542700.0
# 1495              Mesa de noche                  Muebles   294700.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 368           2500.0      11/01/2023  Izabela de León           Pasto
# 796          11200.0      03/03/2022  Izabela de León         Leticia
# 1522          9900.0      16/01/2021    Juliana Costa         Inírida
# 309           2200.0      31/03/2020   Santiago Silva          Bogotá
# 304           3300.0      18/11/2021   Blanca Ramirez    Barranquilla
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ## Ingreso total de cada tienda

# %%
#Ingreso total de cada tienda: Sumando los valores de la columna Precio de cada conjunto de datos de la tienda para estimar los ingresos
ingreso_tienda = tienda['Precio'].sum()
print(ingreso_tienda)
# Out:
# 1150880400.0

# %%
ingreso_tienda2 = tienda2['Precio'].sum()
print(ingreso_tienda2)
# Out:
# 1116343500.0

# %%
ingreso_tienda3 = tienda3['Precio'].sum()
print(ingreso_tienda3)
# Out:
# 1098019600.0

# %%
ingreso_tienda4 = tienda4['Precio'].sum()
print(ingreso_tienda4)
# Out:
# 1038375700.0

# %% [markdown]
# # 2. Ventas por categoría

# %%
#La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
tienda['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda2['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda3['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda4['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
#El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
calificacion_tienda = tienda['Calificación'].mean()
print(f'La calificacion promedio de la tienda 1 es: {calificacion_tienda}')
# Out:
# La calificacion promedio de la tienda 1 es: 3.976685036032217

# %%
calificacion_tienda2 = tienda2['Calificación'].mean()
print(f'La calificacion promedio de la tienda 2 es: {calificacion_tienda2}')
# Out:
# La calificacion promedio de la tienda 2 es: 4.037303942348453

# %%
calificacion_tienda3 = tienda3['Calificación'].mean()
print(f'La calificacion promedio de la tienda 3 es: {calificacion_tienda3}')
# Out:
# La calificacion promedio de la tienda 3 es: 4.048325561678677

# %%
calificacion_tienda4 = tienda4['Calificación'].mean()
print(f'La calificacion promedio de la tienda 4 es: {calificacion_tienda4}')
# Out:
# La calificacion promedio de la tienda 4 es: 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ###Tienda 1

# %%
#Identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda.
#Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

#El siguiente grafico muestra todos los productos y sus cantidades respectivamente
productos = tienda['Producto'].value_counts()
productos.plot(kind='barh', figsize=(10,10), color='pink', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
#A continuacion haré otro gráfico pero solo mostrando los productos mas vendidos y menos vendidos, dejando de lado los productos que se encuentran "en el medio". Es decir, solo tomo los extremos.
#De esta forma la visualizacion de los resultados es un poco mas amena. El mismo procedimiento se realiza para las demas tiendas.

max_tienda = productos.max()
min_tienda = productos.min()
destacados = productos[(productos == max_tienda) | (productos == min_tienda)]

#Productos mas y menos vendidos de la tienda 1

destacados.plot(kind='barh', figsize=(5,5), color='pink', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %% [markdown]
# ###Tienda 2

# %%
#Todos los productos vendidos por la tienda 2
productos2 = tienda2['Producto'].value_counts()
productos2.plot(kind='barh', figsize=(10,10), color='green', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
#Productos mas vendidos y menos vendidos de la tienda 2
max_tienda2 = productos2.max()
min_tienda2 = productos2.min()
destacados2 = productos2[(productos2 == max_tienda2) | (productos2 == min_tienda2)]
destacados2.plot(kind='barh', figsize=(3,3), color='green', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %% [markdown]
# ###Tienda 3

# %%
#Todos los productos vendidos por la tienda 3
productos3 = tienda3['Producto'].value_counts()
productos3.plot(kind='barh', figsize=(10,10), color='purple', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
#Productos mas vendidos y menos vendidos de la tienda 2
max_tienda3 = productos3.max()
min_tienda3 = productos3.min()
destacados3 = productos3[(productos3 == max_tienda3) | (productos3 == min_tienda3)]
destacados3.plot(kind='barh', figsize=(3,3), color='purple', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %% [markdown]
# ###Tienda 4

# %%
#Todos los productos vendidos por la tienda 3
productos4 = tienda4['Producto'].value_counts()
productos4.plot(kind='barh', figsize=(10,10), color='blue', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %%
#Productos mas vendidos y menos vendidos de la tienda 2
max_tienda4 = productos4.max()
min_tienda4 = productos4.min()
destacados4 = productos4[(productos4 == max_tienda4) | (productos4 == min_tienda4)]
destacados4.plot(kind='barh', figsize=(3,3), color='blue', xlabel='Cantidad', ylabel='Producto')
# Out:
# <Axes: xlabel='Cantidad', ylabel='Producto'>

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
#El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda. Sabiendo que el cliente paga el envío.

#Envio promedio de la tienda 1
envio_tienda = tienda['Costo de envío'].mean()
print(f'El envio promedio de la tienda 1 es: {envio_tienda}')
# Out:
# El envio promedio de la tienda 1 es: 26018.60958033065

# %%
envio_tienda2 = tienda2['Costo de envío'].mean()
print(f'El envio promedio de la tienda 2 es: {envio_tienda2}')
# Out:
# El envio promedio de la tienda 2 es: 25216.235693090293

# %%
envio_tienda3 = tienda3['Costo de envío'].mean()
print(f'El envio promedio de la tienda 3 es: {envio_tienda3}')
# Out:
# El envio promedio de la tienda 3 es: 24805.680373039424

# %%
envio_tienda4 = tienda4['Costo de envío'].mean()
print(f'El envio promedio de la tienda 4 es: {envio_tienda4}')
# Out:
# El envio promedio de la tienda 4 es: 23459.457167090754

# %% [markdown]
# ###Análisis del desempeño geográfico

# %%
#Utilice los datos de latitud (lat) y longitud (lon) para mapear las ventas de cada tienda y analizar la distribución geográfica de los productos vendidos.

#Genere gráficos de dispersión o mapas de calor (Heatmaps) para visualizar datos e identificar áreas con la mayor concentración de ventas.

#Explore si algunas tiendas tienen un rendimiento superior o inferior al esperado en determinadas regiones e identifique si existen patrones geográficos que puedan influir en el rendimiento de las tiendas.

import matplotlib.pyplot as plt

# %% [markdown]
# ###Tienda 1

# %%
tienda['Lugar de Compra'].unique()
# Out:
# array(['Bogotá', 'Medellín', 'Cartagena', 'Cali', 'Santa Marta',
#        'Pereira', 'Barranquilla', 'Villavicencio', 'Inírida', 'Cúcuta',
#        'Manizales', 'Neiva', 'Bucaramanga', 'Valledupar', 'Pasto',
#        'Riohacha', 'Armenia', 'Leticia', 'Soacha'], dtype=object)

# %%
#Grafico para la tienda 1

#Como en el código pusimos s = tienda['Precio'] / 1000, el tamaño del círculo es proporcional al valor del producto.
#Es decir, una burbuja grande significa que se realizó una venta de alto valor.

#Ademas, gracias al parámetro alpha=0.5 (transparencia). Un solo punto es clarito y deja ver a través de él. Por lo tanto, si
#en una ciudad hubo muchas ventas en la misma ubicación los puntos se ponen uno encima del otro, por lo que se ven "mas oscuros".

plt.figure(figsize=(8, 6))

plt.scatter(tienda['lon'], tienda['lat'], s=tienda['Precio']/1000 ,alpha=0.5, color='pink')

#Le colocamos los nombres de los lugares de compra
for i, ciudad in enumerate(tienda['Lugar de Compra']):
    plt.text(tienda['lon'].iloc[i], tienda['lat'].iloc[i], ciudad)

#Agregamos titulo, Etiquetas a los ejes y lo mostramos
plt.title('Distribución Geográfica de Ventas')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %% [markdown]
# ###Tienda 2

# %%
#Grafico para la tienda 2
plt.figure(figsize=(8, 6))

plt.scatter(tienda2['lon'], tienda2['lat'], s=tienda2['Precio']/1000 ,alpha=0.5, color='green')

#Le colocamos los nombres de los lugares de compra
for i, ciudad in enumerate(tienda2['Lugar de Compra']):
    plt.text(tienda2['lon'].iloc[i], tienda2['lat'].iloc[i], ciudad)

#Agregamos titulo, Etiquetas a los ejes y lo mostramos
plt.title('Distribución Geográfica de Ventas')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %% [markdown]
# ###Tienda 3

# %%
#Grafico para la tienda 3
plt.figure(figsize=(8, 6))

plt.scatter(tienda3['lon'], tienda3['lat'], s=tienda3['Precio']/1000 ,alpha=0.5, color='purple')

#Le colocamos los nombres de los lugares de compra
for i, ciudad in enumerate(tienda3['Lugar de Compra']):
    plt.text(tienda3['lon'].iloc[i], tienda3['lat'].iloc[i], ciudad)

#Agregamos titulo, Etiquetas a los ejes y lo mostramos
plt.title('Distribución Geográfica de Ventas')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %% [markdown]
# ###Tienda 4

# %%
#Grafico para la tienda 4
plt.figure(figsize=(8, 6))

plt.scatter(tienda4['lon'], tienda4['lat'], s=tienda4['Precio']/1000 ,alpha=0.5, color='blue')

#Le colocamos los nombres de los lugares de compra
for i, ciudad in enumerate(tienda4['Lugar de Compra']):
    plt.text(tienda4['lon'].iloc[i], tienda4['lat'].iloc[i], ciudad)

#Agregamos titulo, Etiquetas a los ejes y lo mostramos
plt.title('Distribución Geográfica de Ventas')
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.grid(True)
plt.show()

# %% [markdown]
# #Informe Final
#
#
# ##1. *Introducción*
#
#
# ####El objetivo de este análisis fue el de evaluar el desempeño de las 4 tiendas que nos fueron dadas (Tienda, Tienda2, Tienda3 y Tienda4), para asi poder determinar cuál representa la mejor opción de negocio para que el Sr. Juan pueda invertir en ella.
#
# ##2. *Ingresos y ventas*
#
# ####Al consolidar los ingresos, observamos que todas las tiendas superan la barrera de los mil millones de pesos, lo que indica un mercado maduro. Al analizar los datos pudimos obtener que:
#
# ####-> La tienda 1 obtuvo un promedio de ventas de $1150880400.0, siendo así la tienda que más ventas generó.
#
# ####Las categorias mas destacadas en esta tienda fueron: Muebles y Electrónicos respectivamente. La categoría menos vendida fue la de: Articulos para el hogar. Los productos mas vendidos, con 60 unidades cada uno, fueron: Microondas, TV LED UHD 4K y Armario. Los productos menos vendidos fueron: Celular ABXY y Auriculares con micrófono. El envío promedio de esta tienda es de $26018.60.
#
# ####-> La tienda 2 obtuvo uno de $1116343500.0.
#
# ####Las categorias mas destacadas y menos destacadas en la tienda 2 fueron las mismas que en la tienda 1. El producto mas vendidos de la tienda 2 fue el libro: "Iniciando en programación". El producto menos vendido fue el Juego de Mesa. El envio promedio de esta tienda es de $25216.23.
#
#
# ####-> La tienda 3 $1098019600.0.
#
# ####Las categorias mas destacadas y menos destacadas en la tienda 3 fueron las mismas que en la tienda 2. El producto mas vendido de la tienda 3 fue el "Kit de Bancas". El producto menos vendido fueron los Bloques de construcción. El envio promedio de esta tienda es de $24805.68.
#
# ####-> Y por último la tienda 4 obtuvo uno de $1038375700.0.
#
# ####Las categorias mas destacadas de la tienda 4 fueron: Muebles y Electrónicos. La categoria menos destacada fue: Instrumentos musicales. El producto mas vendido de esta tienda fue "Cama box" y el menos vendido la guitarra eléctrica. El envio promedio de esta tienda es de $23459.45, siendo asi la tienda con el envio más económico.
#
# ####Esto demuestra que las categorías de Muebles y Electrónicos dominan el mercado en todas las sucursales, lo que sugiere que el Sr. Juan debería enfocar su inventario en estos sectores de alta rotación.
#
# ####Con respecto a la satisfacción por parte del cliente, la tienda que obtuvo la mejor calificación fue la tienda 3 con 4.04 puntos. Luego le sigue la tienda 2 con 4.03 puntos, la tienda 4 con 3.99 puntos y por último la tienda 1 con 3.97 puntos. Esta nota esta evaluada sobre 5 puntos.
#
#
# ##3. *Conclusión*
# ####El Sr. Juan deberia invertir en la Tienda 3: En un mercado tan competitivo, tener la mejor calificación (4.04) asegura recompras y menor gasto en publicidad. Aunque la tienda 1 vende más, la tienda 3 ofrece un balance superior: sus costos de envío son un 4.6% menores que los de la Tienda 1 y su satisfacción es superior. El producto más vendido ("Kit de Bancas") pertenece a la categoría líder (Muebles). Con la alta satisfacción actual, una pequeña inversión en marketing para alcanzar el volumen de la Tienda 1 convertiría a la Tienda 3 en la más rentable de todas.
# ## *La Tienda 3 no es solo una inversión en ventas, es una inversión en una operación eficiente y clientes satisfechos *
